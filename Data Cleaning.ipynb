# %%
import pandas as pd

# %%
df_houses = pd.read_pickle("houses_dataframe.pkl")

# %%
df_houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1101 entries, 0 to 1100
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   address     1101 non-null   object
#  1   zipcode     1101 non-null   object
#  2   sale_price  1101 non-null   object
#  3   beds        1101 non-null   object
#  4   baths       1101 non-null   object
#  5   house_sqft  1101 non-null   object
#  6   lotsize     1101 non-null   object
#  7   year_built  1101 non-null   object
# dtypes: object(8)
# memory usage: 68.9+ KB

# %%
df_houses.head()
# Out:
#                       address  zipcode sale_price beds baths house_sqft  \
# 0  2934 South Bellaire Street  [80222]  [463,500]    2     1      [725]
# 1       1885 West Stoll Place  [80221]  [500,000]    2     1      [987]
# 2            5179 Clay Street  [80221]  [540,000]    2     2    [1,045]
# 3            1115 Cook Street  [80206]  [775,000]    3     2    [1,893]
# 4          3318 Gilpin Street  [80205]  [756,500]    3     2    [2,450]
#
#    lotsize year_built
# 0  [7,150]     [1949]
# 1  [5,720]     [1947]
# 2  [6,250]     [1941]
# 3  [4,459]     [1910]
# 4  [3,390]     [1890]

# %%
# Strip column values out of list format

df_houses["zipcode"] = [i[0] for i in df_houses["zipcode"]]
df_houses["sale_price"] = [i[0] for i in df_houses["sale_price"]]
df_houses["house_sqft"] = [''.join(i) for i in df_houses["house_sqft"]]
df_houses["lotsize"] = [''.join(i) for i in df_houses["lotsize"]]
df_houses["year_built"] = [i[0] for i in df_houses["year_built"]]

df_houses["sale_price"] = [i.split(",") for i in df_houses["sale_price"]]
df_houses["sale_price"] = ["".join(i) for i in df_houses["sale_price"]]

df_houses["house_sqft"] = [i.split(",") for i in df_houses["house_sqft"]]
df_houses["house_sqft"] = ["".join(i) for i in df_houses["house_sqft"]]

df_houses["lotsize"] = [i.split(",") for i in df_houses["lotsize"]]
df_houses["lotsize"] = ["".join(i) for i in df_houses["lotsize"]]

# %%
# Drop irrelevant/missing data

df_houses.drop(df_houses[df_houses["beds"] == "—"].index, inplace = True)
df_houses.drop(df_houses[df_houses["baths"] == "—"].index, inplace = True)
df_houses.drop(df_houses[df_houses["baths"] == "2,408 Sq. Ft."].index, inplace = True)
df_houses.drop(df_houses[df_houses["house_sqft"] == "—"].index, inplace = True)
df_houses.drop(df_houses[df_houses["house_sqft"] == ""].index, inplace = True)
df_houses.drop(df_houses[df_houses["lotsize"] == ""].index, inplace = True)
df_houses.drop(df_houses[df_houses["lotsize"] == ""].index, inplace = True)
df_houses.drop(df_houses[df_houses["year_built"] == "—"].index, inplace = True)

# %%
df_houses["sale_price"] = df_houses["sale_price"].astype(int)
df_houses["beds"] = df_houses["beds"].astype(int)
df_houses["baths"] = df_houses["baths"].astype(int)
df_houses["house_sqft"] = df_houses["house_sqft"].astype(int)
df_houses["lotsize"] = df_houses["lotsize"].astype(int)
df_houses["year_built"] = df_houses["year_built"].astype(int)

# %%
# Remove houses that either have incorrect sale price information. Remove outliers that have...
# ...sale prices greater than $1.5M or lot larger than 1 acre

df_houses.drop(df_houses[df_houses["sale_price"] < 15000].index, inplace = True)
df_houses.drop(df_houses[df_houses["sale_price"] > 1500000].index, inplace = True)
df_houses.drop(df_houses[df_houses["lotsize"] > 43560].index, inplace = True)

# %%
df_houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1006 entries, 0 to 1100
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   address     1006 non-null   object
#  1   zipcode     1006 non-null   object
#  2   sale_price  1006 non-null   int64
#  3   beds        1006 non-null   int64
#  4   baths       1006 non-null   int64
#  5   house_sqft  1006 non-null   int64
#  6   lotsize     1006 non-null   int64
#  7   year_built  1006 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 70.7+ KB

# %%
df_houses.describe()
# Out:
#          sale_price         beds        baths   house_sqft       lotsize  \
# count  1.006000e+03  1006.000000  1006.000000  1006.000000   1006.000000
# mean   7.034230e+05     3.242545     2.269384  2000.779324   5981.924453
# std    2.471501e+05     0.908128     0.916405   810.464704   2337.785910
# min    2.300000e+05     1.000000     1.000000   549.000000   1177.000000
# 25%    5.200000e+05     3.000000     2.000000  1420.000000   4621.250000
# 50%    6.555000e+05     3.000000     2.000000  1887.000000   6098.000000
# 75%    8.250000e+05     4.000000     3.000000  2455.750000   6630.000000
# max    1.500000e+06     6.000000     5.000000  5186.000000  22811.000000
#
#         year_built
# count  1006.000000
# mean   1941.526839
# std      34.992832
# min    1880.000000
# 25%    1914.000000
# 50%    1942.000000
# 75%    1955.750000
# max    2021.000000

# %%
df_houses.to_pickle("houses_dataframe_cleaned.pkl")
